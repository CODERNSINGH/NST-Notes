# %%
# !pip3 install keras jax jaxlib

# %%
# !pip install keras

# %%
import sys; print(sys.executable)
# Out:
# /opt/miniconda3/envs/machine_learning/bin/python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import keras
#       5 from sklearn.model_selection import train_test_split
#
# File /opt/miniconda3/envs/machine_learning/lib/python3.13/site-packages/keras/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import _tf_keras as _tf_keras
#       8 from keras import activations as activations
#       9 from keras import applications as applications
#
# File /opt/miniconda3/envs/machine_learning/lib/python3.13/site-packages/keras/_tf_keras/__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# ...

# %% [markdown]
# ## Data

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
